# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as pt
import numpy as np

# %%
t, f1, f2 = np.loadtxt("qubitResonator_correct_output.dat")
pt.plot(t, f1)
pt.plot(t, f2)
pt.savefig()
pt.show()

# %%
pt.savefig("qr_correct_output.png")

# %%
t, f1, f2 = np.loadtxt("output.dat")
pt.plot(t, f1)
pt.plot(t, f2)
pt.show()
