# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as pt
import numpy as np

# %%
t, f1, f2 = np.loadtxt("output.dat")

# %%
pt.plot(t, f1)
pt.plot(t, f2)
pt.xlim(0, 2.5)
pt.show()

# %%
t, f1, f2 = np.loadtxt("output.dat")
pt.plot(t, f1)
pt.plot(t, f2)
pt.show()
