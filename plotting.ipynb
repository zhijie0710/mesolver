# %%
# %matplotlib inline
import matplotlib.pyplot as pt
import numpy as np

# %%
import qutip as qt

# %%
t,f1,f2,f3,f4,f5,f6,f7,f8,f9,f10 = np.loadtxt("data/spinChain.dat")
#t,f1,f2,f3 = np.loadtxt("output.dat")
pt.figure(figsize=(10,6))
pt.plot(t, f1)
pt.plot(t, f2)
pt.plot(t, f3)
pt.plot(t, f4)
pt.plot(t, f5)
pt.plot(t, f6)
pt.plot(t, f7)
pt.plot(t, f8)
pt.plot(t, f9)
pt.plot(t, f10)

# %%
t,f1,f2,f3,f4,f5,f6,f7,f8,f9,f10 = np.loadtxt("output.dat")
#t,f1,f2,f3 = np.loadtxt("output.dat")
pt.figure(figsize=(10,6))
pt.plot(t, f1)
pt.plot(t, f2)
pt.plot(t, f3)
pt.plot(t, f4)
pt.plot(t, f5)
pt.plot(t, f6)
pt.plot(t, f7)
pt.plot(t, f8)
pt.plot(t, f9)
pt.plot(t, f10)

# %%
t, f1, f2 = np.loadtxt("data/qubitResonator.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|00\rangle$")
s2, = pt.plot(t, f2, label=r"$|11\rangle$")
pt.legend(handles=[s1, s2], loc=5)
pt.xlabel("time")
pt.ylabel("expectation value")
pt.show()

# %%
t, f1, f2 = np.loadtxt("qubitResonator_correct_output.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|00\rangle$")
s2, = pt.plot(t, f2, label=r"$|11\rangle$")
pt.legend(handles=[s1, s2], loc=5)
pt.xlabel("time")
pt.ylabel("expectation value")
pt.savefig("qubitResonator_correct_output.png", dpi=300)
pt.show()

# %%
t, f1, f2 = np.loadtxt("qubitResonator_error_output.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|00\rangle$")
s2, = pt.plot(t, f2, label=r"$|11\rangle$")
pt.ylim(0,1)
pt.legend(handles=[s1, s2], loc=4)
pt.xlabel("time")
pt.ylabel("expectation value")
pt.savefig("qubitResonator_error_output1.png", dpi=300)
pt.show()

# %%
t, f1, f2 = np.loadtxt("qubitResonator_error_output.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|0\rangle$")
s2, = pt.plot(t, f2, label=r"$|1\rangle$")
pt.ylim(0,1)
pt.xlim(0,3)
pt.legend(handles=[s1, s2], loc=5)
pt.xlabel("time")
pt.ylabel("expectation value")
pt.savefig("qubitResonator_error_output2.png", dpi=300)
pt.show()

# %%
t, f1, f2 = np.loadtxt("data/basicTest.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|0\rangle$")
s2, = pt.plot(t, f2, label=r"$|1\rangle$")
pt.legend(handles=[s1, s2], loc=1)
pt.xlabel("time")
pt.ylabel("expectation value")
# pt.savefig("basic_error_output2.png", dpi=300)
pt.show()

# %%
t, f1, f2 = np.loadtxt("data/qtbasicTest.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|0\rangle$")
s2, = pt.plot(t, f2, label=r"$|1\rangle$")
pt.legend(handles=[s1, s2], loc=1)
pt.xlabel("time")
pt.ylabel("expectation value")
pt.show()

# %%
t, f1, f2 = np.loadtxt("basic_error_output.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|0\rangle$")
s2, = pt.plot(t, f2, label=r"$|1\rangle$")
pt.ylim(0,1)
pt.legend(handles=[s1, s2], loc=9)
pt.xlabel("time")
pt.ylabel("expectation value")
pt.savefig("basic_error_output.png", dpi=300)
pt.show()

# %%
t, f1, f2 = np.loadtxt("basic_correct_output.dat")
pt.figure(figsize=(5,3))
s1, = pt.plot(t, f1, label=r"$|0\rangle$")
s2, = pt.plot(t, f2, label=r"$|1\rangle$")
pt.ylim(0,1)
pt.legend(handles=[s1, s2], loc=1)
pt.xlabel("time")
pt.ylabel("expectation value")
pt.ylim(0,1)
pt.xlim(0,15)
pt.savefig("basic_correct_output.png", dpi=300)
pt.show()
